# %% [markdown]
# <a href="https://colab.research.google.com/github/audreyakwenye/DS-Unit-2-Sprint-4-Model-Validation/blob/master/Kaggle_Comp_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install featuretools

# %%
import featuretools as ft
import numpy as np
import pandas as pd

test_features = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vQenhVhjm4qtmrTNBjDOmc-OBH3R2C2aSEt2zcc_vi8UrK_PC2UE5z3yoFSL2jlusX1WYBVioGcFCRQ/pub?gid=922169319&single=true&output=csv')
train_features = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vTp3w9_zUi31NNzZ0CFrYwlfyS7WwD_mBkGgwWQksXjWhHrqtOWz4DbzkXRqxfkBPMwbcrIY6Ui48zW/pub?gid=326426838&single=true&output=csv')
train_labels = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vQOAUDuQIIo4iklp8ZJzJIH2VF_IDL4e1Li_7xg-59ilmh1YhoXU3ymu6tB6EzQUr48dXTzroalfmIQ/pub?gid=26275048&single=true&output=csv')

# %%
train_features.funder = train_features['funder'].fillna(train_features['funder'].mode()[0])
train_features.funder.mode()
# Out:
# 0    Government Of Tanzania
# dtype: object

# %%
train_features.installer = train_features['installer'].fillna(train_features['installer'].mode()[0])
train_features.installer.mode()
# Out:
# 0    DWE
# dtype: object

# %%
# Out:
# 668.1470176767677

# %%
# Out:
# 0

# %%
train_features = train_features[['amount_tsh', 'funder', 'installer', 'date_recorded', 'gps_height',
       'basin', 'district_code',
       'population', 'public_meeting',
       'permit', 'construction_year',
       'extraction_type_class',
       'payment_type',
       'quality_group','quantity_group',
       'source_type', 'source_class',
       'waterpoint_type_group']]

# %%
from sklearn.preprocessing import LabelEncoder
#Auto encodes any dataframe column of type category or object.
def dummyEncode(df):
        columnsToEncode = list(df.select_dtypes(include=['category','object']))
        le = LabelEncoder()
        for feature in columnsToEncode:
            try:
                df[feature] = le.fit_transform(df[feature])
            except:
                print('Error encoding '+feature)
        return df

      
      
     
dummyEncode(train_features)
# Out:
#        amount_tsh  funder  installer  date_recorded  gps_height  basin  \
# 0          6000.0    1369       1518             47        1390      1
# 1             0.0     469        545            309        1399      4
# 2            25.0     825       2048            300         686      5
# 3             0.0    1741       1852            272         263      7
# 4             0.0      20        119            104        1018      4
# 5            20.0     985        390             46        1018      5
# 6             0.0     345        401            186        1018      0
# 7             0.0    1416        390            194        1018      3
# 8             0.0    1842       2007            219        1018      3
# 9             0.0     593        119            125        1018      4
# 10            0.0    1270       1406             25          62      8
# 11          200.0     261        337            293        1062      1
# ...

# %%
# Out:
# 0    Government Of Tanzania
# dtype: object

# %%
# Out:
# 0    DWE
# dtype: object

# %%
test_features2 = test_features[['amount_tsh', 'funder', 'installer', 'date_recorded', 'gps_height',
       'basin', 'district_code',
       'population', 'public_meeting',
       'permit', 'construction_year',
       'extraction_type_class',
       'payment_type',
       'quality_group','quantity_group',
       'source_type', 'source_class',
       'waterpoint_type_group']]

# %%
# !pip install category_encoders
# Out:
# ...
#     100% |████████████████████████████████| 61kB 2.5MB/s
# ...

# %%
import category_encoders as ce

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
#Auto encodes any dataframe column of type category or object.
def dummyEncode(df):
        columnsToEncode = list(df.select_dtypes(include=['category','object']))
        le = LabelEncoder()
        for feature in columnsToEncode:
            try:
                df[feature] = le.fit_transform(df[feature])
            except:
                print('Error encoding '+feature)
        return df


dummyEncode(test_features2)
# Out:
#        amount_tsh  funder  installer  date_recorded  gps_height  basin  \
# 0             0.0     174        214            255        1996      0
# 1             0.0     247        219            255        1569      5
# 2             0.0     247        219            252        1567      0
# 3             0.0     220        259            242         267      7
# 4           500.0      72         75            306        1260      7
# 5             0.0     247        219            283        1685      5
# 6             0.0     247        299             34         550      6
# 7             0.0     221        270            245         234      7
# 8            30.0     872        465            243         584      7
# 9             0.0     409        479            297        1083      5
# 10            5.0     241        104            326        1259      5
# 11            0.0     945       1034            278         608      5
# ...

# %%
X = train_features
X_test = test_features2
y = train_labels['status_group']

# %%
from sklearn.feature_extraction.text import CountVectorizer

vec = CountVectorizer()

X = vec.fit_transform(X)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-ae5cd47bda90> in <module>()
# ----> 1 X.head()
#
# /usr/local/lib/python3.6/dist-packages/scipy/sparse/base.py in __getattr__(self, attr)
#     684             return self.getnnz()
#     685         else:
# --> 686             raise AttributeError(attr + " not found")
#     687
#     688     def transpose(self, axes=None, copy=False):
#
# AttributeError: head not found

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X,y, test_size=.3, random_state = 0)
X_train.shape, X_val.shape, y_train.shape, y_val.shape
# Out:
# ((41580, 18), (17820, 18), (41580,), (17820,))

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
from sklearn.feature_extraction.text import CountVectorizer

rfc = RandomForestClassifier(n_estimators=1000,
                             min_samples_split=6,
                             criterion='gini',
                             max_features='auto',
                             oob_score=True,
                             random_state=1,
                             n_jobs=-1)

rfc.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=6,
#             min_weight_fraction_leaf=0.0, n_estimators=1000, n_jobs=-1,
#             oob_score=True, random_state=1, verbose=0, warm_start=False)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
from sklearn.feature_extraction.text import CountVectorizer

ETC = ExtraTreesClassifier(n_estimators=1000,
                         min_samples_split=10)

ETC.fit(X_train, y_train)
# Out:
# ExtraTreesClassifier(bootstrap=False, class_weight=None, criterion='gini',
#            max_depth=None, max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=10,
#            min_weight_fraction_leaf=0.0, n_estimators=1000, n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
y_pred = ETC.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-124-2b7a6124e509> in <module>()
# ----> 1 y_pred = ETC.predict(X_test)
#       2
#       3
#
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py in predict(self, X)
#     541             The predicted classes.
#     542         """
# --> 543         proba = self.predict_proba(X)
#     544
#     545         if self.n_outputs_ == 1:
#
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py in predict_proba(self, X)
#     581         check_is_fitted(self, 'estimators_')
#     582         # Check data
# --> 583         X = self._validate_X_predict(X)
#     584
#     585         # Assign chunk of trees to jobs
#
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py in _validate_X_predict(self, X)
# ...

# %%
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn import tree
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline 
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import RobustScaler

# %%
predictions = pd.DataFrame(data={'id': test_features['id'], 'status_group': y_pred})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-123-9b04045ef2da> in <module>()
# ----> 1 predictions = pd.DataFrame(data={'id': test_features['id'], 'status_group': y_pred})
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     328                                  dtype=dtype, copy=copy)
#     329         elif isinstance(data, dict):
# --> 330             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     331         elif isinstance(data, ma.MaskedArray):
#     332             import numpy.ma.mrecords as mrecords
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in _init_dict(self, data, index, columns, dtype)
#     459             arrays = [data[k] for k in keys]
#     460
# --> 461         return _arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
# ...

# %%
from google.colab import files
predictions.to_csv('kaggleten.csv', index=False)
files.download('kaggleten.csv')

# %%
from sklearn.model_selection import cross_val_score
from sklearn.datasets import make_blobs
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
accuracy_score(y_val, y_pred)
# Out:
# 0.8026936026936027

# %%
y_pred = clf.predict(X_val)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-88-274cdfc5b64e> in <module>()
# ----> 1 y_pred = clf.predict(X_val)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py in predict(self, X)
#     541             The predicted classes.
#     542         """
# --> 543         proba = self.predict_proba(X)
#     544
#     545         if self.n_outputs_ == 1:
#
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py in predict_proba(self, X)
#     581         check_is_fitted(self, 'estimators_')
#     582         # Check data
# --> 583         X = self._validate_X_predict(X)
#     584
#     585         # Assign chunk of trees to jobs
#
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py in _validate_X_predict(self, X)
#     360                                  "call `fit` before exploiting the model.")
#     361
# ...
